# %%
from uqlm.black_box.luq import LUQScorer

# %%
luq_scorer = LUQScorer()

# %%
sentences = ['Michael Alan Weiner (born March 31, 1942) is an American radio host.', 'Michael Alan Weiner is the host of The Savage Nation.', "Michael Alan Weiner was a good student when he was in American."]

# Other samples generated by the same LLM to perform self-check for consistency
sample1 = "Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country."
sample2 = "Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times."
sample3 = "Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT."

scores = luq_scorer.evaluate(sentences, [sample1, sample2, sample3])
# Out:
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country., nli_proba: [[8.8431832e-04 9.9864346e-01 4.7224146e-04]], nli_label: neutral, score: 0.5
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host., sample: Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times., nli_proba: [[9.9923658e-01 5.7254318e-04 1.9085986e-04]], nli_label: contradiction, score: 0
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT., nli_proba: [[1.4112064e-03 9.9824113e-01 3.4763262e-04]], nli_label: neutral, score: 0.5
# claim: Michael Alan Weiner is the host of The Savage Nation., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country., nli_proba: [[0.9853003  0.00947047 0.00522926]], nli_label: contradiction, score: 0
# claim: Michael Alan Weiner is the host of The Savage Nation., sample: Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times., nli_proba: [[9.9786431e-01 1.9282261e-03 2.0747042e-04]], nli_label: contradiction, score: 0
# claim: Michael Alan Weiner is the host of The Savage Nation., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT., nli_proba: [[1.4366129e-03 9.9766517e-01 8.9819322e-04]], nli_label: neutral, score: 0.5
# claim: Michael Alan Weiner was a good student when he was in American., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country., nli_proba: [[0.01858086 0.9780977  0.00332142]], nli_label: neutral, score: 0.5
# claim: Michael Alan Weiner was a good student when he was in American., sample: Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times., nli_proba: [[9.8898315e-01 1.0639963e-02 3.7682432e-04]], nli_label: contradiction, score: 0
# claim: Michael Alan Weiner was a good student when he was in American., sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT., nli_proba: [[6.1059068e-03 9.9336630e-01 5.2784977e-04]], nli_label: neutral, score: 0.5
# [[0.5 0.  0.5]
#  [0.  0.  0.5]
#  [0.5 0.  0.5]]

# %%
scores
# Out:
# array([0.33333333, 0.16666667, 0.33333333])
