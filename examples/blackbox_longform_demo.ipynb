# %%
from uqlm.black_box.luq import LUQScorer

# %%
luq_scorer = LUQScorer()

# %%
claim_set1 = ['Michael Alan Weiner (born March 31, 1942) is an American radio host.', 'Michael Alan Weiner is the host of The Savage Nation.', "Michael Alan Weiner was a good student when he was in American."]

claim_set2 = ["Michael Alan Weiner (born January 13, 1960) is a Canadian radio host.",
              "He works at The New York Times."]

claim_set3 = ["Michael Alan Weiner (born March 31, 1942) is an American radio host.", "He obtained his PhD from MIT."]

# Other samples generated by the same LLM to perform self-check for consistency
sample1 = "Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country."
sample2 = "Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times."
sample3 = "Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT."

luq_score, entailment_scores = luq_scorer.evaluate([claim_set1, claim_set2, claim_set3], [sample1, sample2, sample3])
# Out:
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host.
#  sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He is the host of The Savage Country.
#  nli_proba: [[4.5949413e-04 7.4442243e-03 9.9209630e-01]]
#  nli_label: entailment
#  score: 1
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host.
#  sample: Michael Alan Weiner (born January 13, 1960) is a Canadian radio host. He works at The New York Times.
#  nli_proba: [[9.9934953e-01 3.3747777e-04 3.1294825e-04]]
#  nli_label: contradiction
#  score: 0
# claim: Michael Alan Weiner (born March 31, 1942) is an American radio host.
#  sample: Michael Alan Weiner (born March 31, 1942) is an American radio host. He obtained his PhD from MIT.
#  nli_proba: [[3.7935711e-04 1.1953622e-02 9.8766696e-01]]
#  nli_label: entailment
#  score: 1
# --------------------------------
# claim: Michael Alan Weiner is the host of The Savage Nation.
# ...

# %%
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 scores
#
# NameError: name 'scores' is not defined
